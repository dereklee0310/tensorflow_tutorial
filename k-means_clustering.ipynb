# %% [markdown]
# **Import libraries**

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Generate training data**

# %%
k = 3
x, y_true = make_blobs(n_samples=256, centers=k)
plt.scatter(x[:, 0], x[:, 1])
plt.show()

# %% [markdown]
# **Train model**

# %%
kmeans = KMeans(k, n_init=10)
kmeans.fit(x)
centroids = kmeans.cluster_centers_

print('centroids:', kmeans.cluster_centers_)
# Out:
# centroids: [[ 3.24540433  3.12758642]
#  [-9.30558273  5.14793836]
#  [ 9.09878358 -8.59191033]]

# %% [markdown]
# **Visualize result**

# %%
y_predicted = kmeans.predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_predicted)
plt.scatter(centroids[:, 0], centroids[:, 1], c='r', edgecolors='k')
plt.show()
